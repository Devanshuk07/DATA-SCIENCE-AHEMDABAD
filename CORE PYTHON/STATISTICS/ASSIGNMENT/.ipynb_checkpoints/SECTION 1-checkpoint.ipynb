# %%
'''List 5 daily actions you perform on apps like Instagram, Zomato, or Flipkart, and for each, 
identify whether the data generated is numerical or categorical.

| Daily Action                    | App Example | Data Generated                              | Type of Data    |
| ------------------------------- | ----------- | ------------------------------------------- | --------------- |
| Liking a post                   | Instagram   | Like Count (Liked/Not Liked)                | **Numerical**   |
| Giving a restaurant rating      | Zomato      | Rating (e.g., 4.5/5)                        | **Numerical**   |
| Ordering food                   | Zomato      | Food category (Pizza, Burger, South Indian) | **Categorical** |
| Checking product price          | Flipkart    | Product price (₹1,499)                      | **Numerical**   |
| Viewing the number of followers | Instagram   | Follower count (e.g., 2,350)                | **Numerical**   |

Explanation
Numerical data: Data represented by numbers that can be measured or counted (price, rating, followers, quantity, etc.).
Categorical data: Data represented by names, labels, or categories (food type, liked/not liked, payment method, product category, etc.).'''

# %%
'''Given this sample data from a music app: ['Pop', 'Rock', 'Jazz', 'Hip-Hop', 'Pop', 'Rock', 'Jazz', 'Pop'], 
classify the type of data and explain your reasoning in 2-3 lines.'''

'''['Pop', 'Rock', 'Jazz', 'Hip-Hop', 'Pop', 'Rock', 'Jazz', 'Pop']-->this is the genre(categorical) of a music which means 
which type of music a perticular person likes'''

# %%
'''Pick any one feature from an app you use (such as the number of likes on an Instagram post, or the rating of a restaurant on Zomato) and 
describe how statistics could help improve that feature for users.'''

'''i use instagram and it contains social feature means you express your feelings,your social life to your friends and also public.
it includes sharing photos,videos with current location or the location you have visited.

statistics helps in:
-Instagram records the number of likes, comments, shares, saves, and views on every uploaded post.
-It compares these statistics across millions of posts to understand what type of content people enjoy the most.
-If statistics show that short videos (Reels) receive more views and shares than long videos, Instagram will recommend users upload more Reels.
-If posts uploaded at 7 PM usually receive more engagement than posts uploaded at 10 AM, Instagram may suggest the best time to post.
-Statistics also help Instagram decide which uploaded photos and videos should appear on the Explore page by identifying posts with high engagement.
-it can also show the user which videos are trending and according to it type means funny or horror it will help creator by advicing to create such more videos.

Benefit to Users:
Statistics help Instagram recommend the best time to upload, promote engaging photos and videos to more people, and provide creators with insights 
so they can create better content and reach a larger audience.'''

# %%
'''Suppose you are building a new playlist recommendation feature for a Spotify-like app. List 3 basic statistical terms 
(such as mean, median, mode, variance, etc.) that would be useful in analyzing user listening data, and explain each with a one-line example.'''

'''mean--it will help in finding overall average time of a perticular user.if a person is listing songs for an average 90min a day so the app can recommoded
new songs to play for longer time increment.

mode-- means it is used to see which song is most like or most listened by people and so it means it is frequently played.you can also find how much times a perticular song so that a specific
type of that genre liking person can be recommeded with the same.'''

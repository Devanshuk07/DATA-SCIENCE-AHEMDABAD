# %%
'''List 3 examples of 'population' and 'sample' in the context of apps you use daily (like Instagram followers, Zomato restaurants, or Flipkart products).
For each, clearly define what would be considered the population and what would be a sample.'''

# for instagram followers
insta_population = [
    120, 340, 560, 890, 1020,
    1340, 1560, 1780, 2100, 2450,
    2800, 3100, 3550, 3900, 4200,
    4700, 5100, 5600, 6100, 6800,
    7200, 7800, 8400, 9100, 9800,
    10500, 11300, 12100, 13000, 14200,
    15500, 16800, 18200, 19500, 21000,
    22500, 24100, 25800, 27600, 29500,
    31500, 33800, 36200, 38700, 41300,
    44000, 46800, 49700, 52800, 56000
]
insta_sample = [7200, 7800, 8400, 9100, 9800]

# for zomato restaurant

zomato_population = [
    120, 150, 180, 200, 220,
    240, 260, 280, 300, 320,
    340, 360, 380, 400, 420,
    450, 470, 500, 530, 560,
    590, 620, 650, 680, 710,
    740, 780, 820, 860, 900,
    950, 1000, 1060, 1120, 1180,
    1250, 1320, 1400, 1480, 1560,
    1650, 1750, 1860, 1980, 2100,
    2230, 2370, 2520, 2680, 2850
]

zomato_sample = [740, 780, 820, 860, 900]

# for flipkart products

flipkart_population = [
    299, 349, 399, 449, 499,
    549, 599, 649, 699, 749,
    799, 849, 899, 949, 999,
    1099, 1199, 1299, 1399, 1499,
    1599, 1699, 1799, 1899, 1999,
    2199, 2399, 2599, 2799, 2999,
    3199, 3499, 3799, 4099, 4399,
    4699, 4999, 5499, 5999, 6499,
    6999, 7599, 8199, 8899, 9599,
    10399, 11299, 12199, 13299, 14599
]
flipkart_sample = [2199, 2399, 2599, 2799, 2999]

# %%
'''Write a Python script that simulates random sampling: given a list of 1000 fake user IDs (e.g., user1 to user1000), select 50 random users to simulate a survey sample. 
Print the selected user IDs.<br><br><em><strong>Hint:</strong> Use the random.sample() function from Python's random module.</em>'''
import random
user_ids=[random.randint(100000,999999)for _ in range(1000)]
print(user_ids)
sample_users = random.sample(user_ids,50)
print(sample_users)
print(len(user_ids))
# Out:
# [496339, 666085, 111091, 856562, 120146, 709830, 953545, 799307, 208941, 305939, 797137, 843906, 311136, 359914, 962104, 571110, 954039, 519592, 636495, 502627, 887842, 401694, 676508, 198861, 429212, 103713, 193371, 742790, 462050, 209585, 269442, 453202, 443734, 947303, 726582, 598366, 992815, 565273, 502869, 767943, 910542, 168227, 669658, 501638, 933634, 473816, 370386, 277627, 389755, 471684, 233846, 850463, 411415, 339884, 956563, 807243, 170854, 754256, 233085, 827462, 330350, 514494, 538418, 471211, 591168, 983627, 980359, 237839, 304341, 844911, 525577, 643011, 959960, 733690, 466035, 307942, 888698, 969690, 290711, 868652, 549044, 768635, 605364, 783241, 220242, 789865, 998946, 572532, 857516, 469781, 925754, 870283, 379597, 552105, 806447, 977431, 266499, 695721, 526271, 815047, 357866, 253156, 746197, 180910, 521503, 570415, 608224, 466485, 442230, 997957, 837787, 149417, 767283, 101505, 965924, 442071, 665496, 903213, 719195, 640300, 269002, 472292, 927649, 618150, 49553
# ...

# %%
'''Imagine you are analyzing food delivery times on Swiggy. 
Explain in 2-3 sentences why you would use sampling instead of collecting data from every single order ever made.'''

'''I would use sampling because collecting data from every single Swiggy order would take a lot of time, money, and computing resources.
A well-chosen sample of orders can accurately represent the entire population, 
allowing you to analyze delivery times and make reliable conclusions much more efficiently.'''

# %%
'''Given this scenario: A survey about music preferences is only sent to users who recently streamed Bollywood songs on Spotify.
Identify and explain the type of bias this introduces in the sample.'''

'''The survey is sent only to users who recently streamed Bollywood songs, so the sample does not represent all Spotify users. People who prefer genres like pop, rock, classical, hip-hop, or podcasts are excluded, making the survey results biased toward Bollywood listeners and not representative of the entire user population.'''

# %%
'''Choose any two types of sampling (for example: random sampling, stratified sampling, systematic sampling, cluster sampling).
For each, describe how you would use it to select a sample of users from BookMyShow to study movie booking habits.'''

'''1. Random Sampling

In random sampling, every BookMyShow user has an equal chance of being selected. I would randomly select, for example, 500 users

2. Stratified Sampling

In stratified sampling, the users are divided into groups (strata) based on a characteristic, such as age group, city, or subscription type.'''

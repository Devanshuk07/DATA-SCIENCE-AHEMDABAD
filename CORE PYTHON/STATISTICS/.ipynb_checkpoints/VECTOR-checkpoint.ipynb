# %%
'''WHAT IS VECTOR ?
-thing that has direction and magnitude both is called vector.

embadding:- from text to vector means words is converted to array
numpy is 3d so after that vector we have to use for 20d like that.

vector addition=vector_a+vector_b
scaler multiplier=scaler * vector_a
dot product=np.dot(vector_a,vector_b)

in dot product both matrix a and b both has to be same means (2x2) of a and (2x2) of b like that (2x3) of a and (3x4) of b can also perform dot matrix.just 3 and 3 must be same.

# %%
'''what is matrix:--

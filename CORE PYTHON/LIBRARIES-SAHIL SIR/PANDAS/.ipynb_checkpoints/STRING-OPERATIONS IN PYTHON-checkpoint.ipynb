# %%
import pandas as pd
import numpy as np

data={'name':['Devanshu Khakhar','Viral Sharma','Manoj Verma','Devanshu Khakhar','Jay Popat']}
df=pd.DataFrame(data)
df
df['name'].str.upper()
df['name'].str.replace('Devanshu','KD',regex=True)   # regex means taking all the similar value together.
df['name'].str.contains('Devanshu',case=False)     # case means case sensitive is true means devanshu or Devanshu both same.
df['split_new']=df['name'].str.split(' ')
df
# Out:
#                name            split_new
# 0  Devanshu Khakhar  [Devanshu, Khakhar]
# 1      Viral Sharma      [Viral, Sharma]
# 2       Manoj Verma       [Manoj, Verma]
# 3  Devanshu Khakhar  [Devanshu, Khakhar]
# 4         Jay Popat         [Jay, Popat]

# %%
'''ARITHMETIC OPRATORS:-
1)ARITHMETIC-- (-+*/),(//-FLOOR DIVISION),(%-MODULS),(**-EXPONENET)
2)RELATIONAL OPERATOR:-(<,>,<=,>=,==,!=)total=6
3)ASSIGNMENT OPERATOR--(TO GIVE SOME VALUE/ASSIGN)
4)LOGICAL/BOOLEAN OPERATOR:-(AND,OR,NOT)
5)IDENTITY OPERATOR:-IS OR NOT IS
6)MEMBERSHIP:-TO CHECK IT IS MEMBER OR NOT (IN AND NOT IN)
7)BITWISE:-101011101010 FORMAT(BINARY VALUES)

# %%
'''MODULS:-(%-REMINDER)'''
a=int(input("ENTER THE NUMBER 1 :-"))
b=int(input("ENTER THE NUMBER 2 :-"))
print(f"MODULES OF {a} And {b} is {a%b}")
# Out:
# ENTER THE NUMBER 1 :- 30
# ENTER THE NUMBER 2 :- 3
# MODULES OF 30 And 3 is 0

# %%
'''EXPONENT:-(2 RAISE TO 3= 2**3)'''
a=int(input("ENTER THE NUMBER 1 :-"))
b=int(input("ENTER THE NUMBER 2 :-"))
print(f"MODULES OF {a} And {b} is {a**b}")
# Out:
# ENTER THE NUMBER 1 :- 3
# ENTER THE NUMBER 2 :- 4
# MODULES OF 3 And 4 is 81

# %%
'''ASSIGNMENT OPERATORS:-(TO GIVE SOME VALUE/ASSIGN)'''
a=10
#then increase it by 5
a+=5
a*=5
b=a//3
print(a)
print(f"{a+20}")  # YOU CANNOT ASSIGN VALUE IN PRINT MEANS YOU CANNOT USE = IN PRINT
print(b)
# Out:
# 75
# 95
# 25

# %%
'''RELATIONAL OPERATORS:-(<,>,<=,>=,==,!=)total=6'''
a=int(input("ENTER VALUE OF 1 :- "))
b=int(input("ENTER VALUE OF 2 :- "))
c=a>b
print(f"{a}>{b}is{c}")
# Out:
# ENTER VALUE OF 1 :-  10
# ENTER VALUE OF 2 :-  2
# 10>2isTrue

# %%
a=int(input("ENTER VALUE OF 1 :- "))
b=int(input("ENTER VALUE OF 2 :- "))
c=a<b
print(f"{a}<{b}is{c}")
# Out:
# ENTER VALUE OF 1 :-  10
# ENTER VALUE OF 2 :-  20
# 10<20isTrue

# %%
a=int(input("ENTER VALUE OF 1 :- "))
b=int(input("ENTER VALUE OF 2 :- "))
c=a>=b
print(f"{a}>={b}is{c}")
# Out:
# ENTER VALUE OF 1 :-  10
# ENTER VALUE OF 2 :-  10
# 10>=10isTrue

# %%
a=int(input("ENTER VALUE OF 1 :- "))
b=int(input("ENTER VALUE OF 2 :- "))
c=a<=b
print(f"{a}<={b}is{c}")
# Out:
# ENTER VALUE OF 1 :-  10
# ENTER VALUE OF 2 :-  10
# 10<=10isTrue

# %%
a=int(input("ENTER VALUE OF 1 :- "))
b=int(input("ENTER VALUE OF 2 :- "))
c=a==b
print(f"{a}=={b}is{c}")
# Out:
# ENTER VALUE OF 1 :-  10
# ENTER VALUE OF 2 :-  20
# 10==20isFalse

# %%
a=int(input("ENTER VALUE OF 1 :- "))
b=int(input("ENTER VALUE OF 2 :- "))
c=a!=b
print(f"{a}!={b}is{c}")
# Out:
# ENTER VALUE OF 1 :-  5
# ENTER VALUE OF 2 :-  10
# 5!=10isTrue

# %%
'''LOGICAL OPERATORS:-(AND,OR,NOT) / ALSO CALLED BOOLEAN OPERATORS...
COMBINE TWO OR MORE CONDITION THEN WE HAVE TO USE THIS OPERATOR...'''
a=int(input("ENTER VALUE OF 1 :- "))
b=int(input("ENTER VALUE OF 2 :- "))
#c=a>b and a>100
#print(c)
print(F"{a}>{b}and{a}>100 =={a>b and a>100}")

#FALSE AND TRUE == FALSE
#TRUE AND TRUE  == TRUE
#FALSE AND FALSE ==FALSE
# Out:
# ENTER VALUE OF 1 :-  101
# ENTER VALUE OF 2 :-  20
# 101>20and101>100 ==True

# %%
# OR EXAMPLE:-
a=int(input("ENTER VALUE OF 1 :- "))
b=int(input("ENTER VALUE OF 2 :- "))
#c=a>b or a>100
#print(c)
print(F"{a}>{b}or{a}>100 =={a>b or a>100}")
# Out:
# ENTER VALUE OF 1 :-  200
# ENTER VALUE OF 2 :-  202
# 200>202or200>100 ==True

# %%
#NOT EXAMPLE:-
a=int(input("ENTER VALUE OF 1 :- "))
b=int(input("ENTER VALUE OF 2 :- "))
#c=a>b and a>100
#print(c)
print(F"{a}!={b}or{a}!=100 =={a!=b or a!=100}")
# Out:
# ENTER VALUE OF 1 :-  100
# ENTER VALUE OF 2 :-  200
# 100!=200or100!=100 ==True

# %%
'''MEMBERSHIP:-TO CHECK IT IS MEMBER OR NOT (IN AND NOT IN)'''
name="devanshu"
print("d" in name)
print("es" in name) # must be together...as in name same.
# Out:
# True
# False

# %%
'''IDENTITY OPERATOR:-IS OR NOT IS'''
a=10
b=20
#c=20
c=a
print(a is b)
print(b is c)
print(c is a)

print(id(a)) # ID IS FOR UNIQUE function ID USED IN PYTHON...
print(id(b))
print(id(c))  # ID IS SAME AS A BECAUSE BOTH C=A SAME.

#TYPE ALSO A FUNCTION RETURNS WHICH TYPE OF VALUE IT IS:-
print(type(a))

to_do=[]
to_bo={}
to_mo=()

print(type(to_do))
print(type(to_bo))
print(type(to_mo))
# Out:
# False
# False
# True
# 140731509286296
# 140731509286616
# 140731509286296
# <class 'int'>
# <class 'list'>
# <class 'dict'>
# <class 'tuple'>

# %%
'''BITWISE OPERATOR:- CONVERT TO BINARY OR MACHINE LEVEL LANGUAGE(10101101010)'''
a=10
# in binary 10-- 1010(done in calculator)
b=5
# in binary 5-- 0101(done in calculator)
#then addition of a+b in binary will be
'''
10==1010 | 5==0101  WILL BE 1111. (|-IS OR and in or any one true will return true always.)
10==1010 & 5==0101  WILL BE 0000. (&-IS ADD and in and both must be true then it will retun true or false)

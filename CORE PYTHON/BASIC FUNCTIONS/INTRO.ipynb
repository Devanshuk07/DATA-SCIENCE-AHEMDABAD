# %%
'''BASIC FUNCTIONS IN PYTHON:-
FUNCTIONS--(ALWAYS USED TO PERFORM SPECIFIC TASK)
2 TYPE:
1)IN-BUILT
2)USER DEFINE

# %%
'''
1)IN-BUILT:
ALREADY IN LIBRARY.
2)USER DEFINE:
CREATED BY USER/PROGRAMER.(EX:-FIND FACTORIAL)

# %%
'''
1)IN-BUILT
PARAMETER
RETURN TYPE
-PRINT---TO PRINT SOMETHING (SEP,END)
-INPUT---TO TAKE INPUT FROM USER.
VARIABLE---IDENTIFIER, WHOSE VALUE CAN BE CHANGED.

# %%
'''PROGRAM'''
name="DEVANSHU"
print(name)
# Out:
# DEVANSHU

# %%
a="hello world"
b="what is your name"
print(a,b)
# Out:
# hello world what is your name

# %%
print("hello world",end=" ")   # END IS USED TO ADD STR IN ONE LINE PRINT IN ONE LINE.
print("what is your name")
# Out:
# hello world what is your name

# %%
print("hello world","what is your name",sep="##")  #SEP(seperate) IS USED IF IN A SINGLE PRINT TWO STATEMNET IS GIVEN THEN IT WILL USED LIKE THIS.
#SEP WILL NOT BE USED IN SINGLE PRINT STATEMENT.
# Out:
# hello world##what is your name

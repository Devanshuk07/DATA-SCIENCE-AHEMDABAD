# %%
fname=input("WHAT IS YOUR FIRST NAME :")
print(fname)
lname=input("WHAT IS YOUR LAST NAME :")
print(lname)
name=fname+" "+lname    # " " is used for space... in output.
print(name)
# Out:
# WHAT IS YOUR FIRST NAME : devanshu
# devanshu
# WHAT IS YOUR LAST NAME : khakhar
# khakhar
# devanshu khakhar

# %%
'''variables--identifiers
RULES:-
CASE SENSITIVE.
STARTS WITH ALWAYS LETTER.
_ IS ALLOWED.
@ NOT ALLOWED.'''

'''BASIC INPUT IT WILL BE STRING ONLY...'''

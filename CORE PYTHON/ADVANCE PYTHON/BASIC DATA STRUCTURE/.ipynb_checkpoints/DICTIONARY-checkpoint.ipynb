# %%
'''DICTIONARY:-(PAIR OF KEY AND VALUES){KEY:VALUE} BRACKETS :---- {}
MUTABLE:-ALLOW CHANGES.(DICT IS MUTABLE BUT ITS KEYS MUST BE IMMUTABLE)
INDEXING BY KEYS.
ORDERED
NO DUPLTICATE KEYS BUT ALLOW DUPLICATE VALUES
-COMPREHENSIVE/COMPREHENSION..'''

# %%
a={'name':'devanshu','age':27,'address':'sweet home','age':29}  #IF 2 VALUES AGE THEN TAKES THE LAST ONE MEANS LATEST.
a['name']='devanshu khakhar'
print(a)
print(a['age'])
print(a.keys())
print(a.values())
print(a.items())
# Out:
# {'name': 'devanshu khakhar', 'age': 29, 'address': 'sweet home'}
# 29
# dict_keys(['name', 'age', 'address'])
# dict_values(['devanshu khakhar', 29, 'sweet home'])
# dict_items([('name', 'devanshu khakhar'), ('age', 29), ('address', 'sweet home')])

# %%
a={'name':'devanshu','age':27,'address':'sweet home','age':29}  #IT WILL TAKE THE LATEST/LAST GIVEN AGE.
for k,v in a.items():
    print(f'{k}:-{v}')
# Out:
# name:-devanshu
# age:-29
# address:-sweet home

# %%
# HOW TO MERGE TWO DICTIONARY :--
d1 = {'a': 1, 'b': 2}
d2 = {'b': 3, 'c': 4}
d3=d1.copy()
d3.update(d2)
print(d3)
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %%
'''d = {'a': 10, 'b': 20}

# 1. Create d2 using: d2 = d
# 2. Create d3 using: d.copy()

# 3. Modify d['a'] = 100

# 4. Print d, d2, d3
# 5. Explain output'''

# %%
d = {'a': 10, 'b': 20}
d2=d
d3=d.copy()
print(d3)
d['a']=100
print(d,d2,d3)
'''here first in d2 we have given d2=d so the dict for d is assigned to d2 then d3 is a copy of d so
d3 has value of d but when d is changed then it will not affect the d3.'''
# Out:
# {'a': 10, 'b': 20}
# {'a': 100, 'b': 20} {'a': 100, 'b': 20} {'a': 10, 'b': 20}

# %%
# a={'name':'pratham','age':22,'place':'paldi','email':'pratha@gmail.com',
#   'name':'vijay','age':20,'place':'jaipur','email':'vijay@gmail.com',
#   'name':'abhi','age':30,'place':'rajkot','email':'abhi@gmail.com',
#   'name':'jay','age':25,'place':'goa','email':'jay@gmail.com'}
a={'name':['vijay','pratham','abhi','jay','meet'],
   'age':[22,30,25,32,12],
   'place':['paldi','rajkot','goa','jaipur','mela'],
   'email':['vijay@gmail.com','pratham@gmail.com','abhi@gmail.com','jay@gmail.com','meet@gmail.com'],
}
#print(a)
for k,v in a.items():
    print(k)
    for i in v:
        print('\t',i)
# Out:
# name
# 	 vijay
# 	 pratham
# 	 abhi
# 	 jay
# 	 meet
# age
# 	 22
# 	 30
# 	 25
# 	 32
# 	 12
# place
# 	 paldi
# 	 rajkot
# 	 goa
# 	 jaipur
# 	 mela
# email
# 	 vijay@gmail.com
# 	 pratham@gmail.com
# 	 abhi@gmail.com
# 	 jay@gmail.com
# 	 meet@gmail.com

# %%
#NESTED DICTIONARY:-
a={'name':'pratham',
   'age':20,
   'marks':[90,50,70]
  }
marks=a['marks']
total_marks=sum(marks)
print(total_marks)
a['total']=total_marks    #ADDING TO A. by a[add here]
print(a)
# Out:
# 210
# {'name': 'pratham', 'age': 20, 'marks': [90, 50, 70], 'total': 210}

# %%
#We have multi employees with name,dept,salary,age,key employees.
emp={'emp101':                                                  #HERE EMP101 IS -->K
     {'name':'kd','age':21,'salary':20000,'dept':'finance'},
     'emp201':
     {'name':'rutu','age':23,'salary':23000,'dept':'teacher'},
     'emp301':
     {'name':'meet','age':25,'salary':25000,'dept':'software'},
    }
#display emp salary more than 20000:-
#display emp who works in software dept:-
#display emp whose age is more than 25:-
#display emp whos empid is selected/entered.
for k,v in emp.items():
    if emp[k]['salary']>20000:            # here emp is main dict and [k] means--->emp101 then in it [salary].
        print(f'here emp id is :-{k},{emp[k]['name'],emp[k]['salary']}')
# Out:
# here emp id is :-emp201,('rutu', 23000)
# here emp id is :-emp301,('meet', 25000)

# %%
#display emp who works in software dept:-
emp={'emp101':                                                  #HERE EMP101 IS -->K
     {'name':'kd','age':21,'salary':20000,'dept':'finance'},
     'emp201':
     {'name':'rutu','age':23,'salary':23000,'dept':'teacher'},
     'emp301':
     {'name':'meet','age':25,'salary':25000,'dept':'software'},
    }
for k,v in emp.items():
    if emp[k]['dept']=='software':
        print(k,emp[k]['name'],emp[k]['dept'])
# Out:
# emp301 meet software

# %%
#display emp whos empid is selected/entered:-
emp={'emp1':                                                  #HERE EMP101 IS -->K //emp1 is key and name:kd and all is its value.
     {'name':'kd','age':21,'salary':20000,'dept':'finance'},
     'emp2':
     {'name':'rutu','age':23,'salary':23000,'dept':'teacher'},
     'emp3':
     {'name':'meet','age':25,'salary':25000,'dept':'software'},
    }
b=input('ENTER THE ID OF EMP:-')
for k,v in emp.items():      # HERE K IS KEY,V IS VALUE AND EMP[K] IS ALSO VALUES.
    if b==k:
        print(v['name'],v['salary'],v['dept'])   # just v means values of dict.
# Out:
# ENTER THE ID OF EMP:- emp3
# meet 25000 software

# %%
#Search by Type (EV/Petrol/Deisel) :
car={'ev':                                  #HERE 'EV'-->K means keys
     {'maruti':{'baleno':{'price':1000000,'model':1},    #HERE MARUTI:BALENO:PRICE,MODEL ARE VALUES.
                'scross':{'price':1100000,'model':1}     #Left side = key $ Right side = value.
               },
      'hundai':{'i10':{'price':1200000,'model':1},
                'creta':{'price':1600000,'model':1}
               },
      'kia':{'seltos':{'price':1900000,'model':1},
             'sonet':{'price':1500000,'model':1}
            }
     },
     'petrol':{'maruti':{'baleno':{'price':700000,'model':1},
                         'scross':{'price':800000,'model':1}
                        },
               'hundai':{'i10':{'price':700000,'model':1},
                         'creta':{'price':1200000,'model':1}
                        },
               'kia':{'seltos':{'price':1400000,'model':1},
                      'sonet':{'price':1100000,'model':1}
                     },
               'tata':{'altroz':{'price':700000,'model':1},
                       'punch':{'price':600000,'model':1}
                      }
              },
     'diesel':{'maruti':{'baleno':{'price':1000000,'model':1},
                         'scross':{'price':900000,'model':1}
                        },
               'hundai':{'i10':{'price':800000,'model':1},
                         'creta':{'price':1400000,'model':1}
                        },
               'kia':{'seltos':{'price':1600000,'model':1},
                      'sonet':{'price':1200000,'model':1}
                     }
              }
}
b=input("ENTER THE VARIANT CAR YOU WANT:-").lower()
for k,v in car.items():                    #THIS K,V IS FOR K ONLY MEANS CATEGORIE.
            if b==k:
                print(f' categorie: {b}')
for company, car in v.items():            #IT WILL GO IN maruti → {baleno, scross}--->v.items.
    print('\n'f' COMPANY NAME: {company.upper()}')
    for car_name, details in car.items():  #IT WILL GO IN CARS.ITEM MEANS baleno → {price, model}
        print(f"Car Name: {car_name} | Price: {details['price']} | Model: {details['model']}")

        #AS DATA IS INSIDE DATA SO WE HAVE TO WRITE 3 FOR LOOPS.(nested structure)
        # for v.items--->maruti → {baleno, scross}
        # for car.items---> baleno → {price, model}
# Out:
# ENTER THE VARIANT CAR YOU WANT:- ev
#  categorie: ev
#
#  COMPANY NAME: MARUTI
# Car Name: baleno | Price: 1000000 | Model: 1
# Car Name: scross | Price: 900000 | Model: 1
#
#  COMPANY NAME: HUNDAI
# Car Name: i10 | Price: 800000 | Model: 1
# Car Name: creta | Price: 1400000 | Model: 1
#
#  COMPANY NAME: KIA
# Car Name: seltos | Price: 1600000 | Model: 1
# Car Name: sonet | Price: 1200000 | Model: 1

# %%
#Search by Car (Seltos,Sonate,i10,creata....)
car={'ev':                                  
     {'maruti':{'baleno':{'price':1000000,'model':1},    
                'scross':{'price':1100000,'model':1}     
               },
      'hundai':{'i10':{'price':1200000,'model':1},
                'creta':{'price':1600000,'model':1}
               },
      'kia':{'seltos':{'price':1900000,'model':1},
             'sonet':{'price':1500000,'model':1}
            }
     },
     'petrol':{'maruti':{'baleno':{'price':700000,'model':1},
                         'scross':{'price':800000,'model':1}
                        },
               'hundai':{'i10':{'price':700000,'model':1},
                         'creta':{'price':1200000,'model':1}
                        },
               'kia':{'seltos':{'price':1400000,'model':1},
                      'sonet':{'price':1100000,'model':1}
                     },
               'tata':{'altroz':{'price':700000,'model':1},
                       'punch':{'price':600000,'model':1}
                      }
              },
     'diesel':{'maruti':{'baleno':{'price':1000000,'model':1},
                         'scross':{'price':900000,'model':1}
                        },
               'hundai':{'i10':{'price':800000,'model':1},
                         'creta':{'price':1400000,'model':1}
                        },
               'kia':{'seltos':{'price':1600000,'model':1},
                      'sonet':{'price':1200000,'model':1}
                     }
              }
}
b=input("ENTER THE CAR NAME YOU WANT:-").lower()
for fuel_type, companies in car.items():              # fuel_type:-ev / petrol / diesel and companies:-many companies 
    for company, cars in companies.items():           # company(individual):-maruti / kia / hundai and cars:-many cars
        for car_name, details in cars.items():        # car_name:-seltos / i10 / creta and details:-full detail of every cars.
            if b in car_name:
                print(f'FUEL TYPE:-{fuel_type} | PRICE:-{details['price']}| MODEL:-{details['model']}')
# Out:
# ENTER THE CAR NAME YOU WANT:- seltos
# FUEL TYPE:-ev | PRICE:-1900000| MODEL:-1
# FUEL TYPE:-petrol | PRICE:-1400000| MODEL:-1
# FUEL TYPE:-diesel | PRICE:-1600000| MODEL:-1

# %%
#Search by Type (EV/Petrol/Deisel) :
car={'ev':                                  #HERE 'EV'-->K means keys
     {'maruti':{'baleno':{'price':1000000,'model':1},    #HERE MARUTI:BALENO:PRICE,MODEL ARE VALUES.
                'scross':{'price':1100000,'model':1}     #Left side = key $ Right side = value.
               },
      'hundai':{'i10':{'price':1200000,'model':1},
                'creta':{'price':1600000,'model':1}
               },
      'kia':{'seltos':{'price':1900000,'model':1},
             'sonet':{'price':1500000,'model':1}
            }
     },
     'petrol':{'maruti':{'baleno':{'price':700000,'model':1},
                         'scross':{'price':800000,'model':1}
                        },
               'hundai':{'i10':{'price':700000,'model':1},
                         'creta':{'price':1200000,'model':1}
                        },
               'kia':{'seltos':{'price':1400000,'model':1},
                      'sonet':{'price':1100000,'model':1}
                     },
               'tata':{'altroz':{'price':700000,'model':1},
                       'punch':{'price':600000,'model':1}
                      }
              },
     'diesel':{'maruti':{'baleno':{'price':1000000,'model':1},
                         'scross':{'price':900000,'model':1}
                        },
               'hundai':{'i10':{'price':800000,'model':1},
                         'creta':{'price':1400000,'model':1}
                        },
               'kia':{'seltos':{'price':1600000,'model':1},
                      'sonet':{'price':1200000,'model':1}
                     }
              }
}
b=input("ENTER THE VARIANT CAR YOU WANT:-").lower()

for fuel_type,companies in car.items():
    if b in fuel_type:
        print('\n'f'FUEL TYPE:-{b}')
        for company,cars in companies.items():
            print('\n'f'COMPANY NAME:-{company}')
            for car_name,details in cars.items():
                print(f'CAR NAME:- {car_name} | PRICE:- {details['price']} | MODEL:- {details['model']}')
# Out:
# ENTER THE VARIANT CAR YOU WANT:- ev
# FUEL TYPE:-ev
#
# COMPANY NAME:-maruti
# CAR NAME:- baleno | PRICE:- 1000000 | MODEL:- 1
# CAR NAME:- scross | PRICE:- 1100000 | MODEL:- 1
#
# COMPANY NAME:-hundai
# CAR NAME:- i10 | PRICE:- 1200000 | MODEL:- 1
# CAR NAME:- creta | PRICE:- 1600000 | MODEL:- 1
#
# COMPANY NAME:-kia
# CAR NAME:- seltos | PRICE:- 1900000 | MODEL:- 1
# CAR NAME:- sonet | PRICE:- 1500000 | MODEL:- 1

# %%
#Search by Company (Kia,Hundai,Maruti...):-
car={'ev':                                  #HERE 'EV'-->K means keys
     {'maruti':{'baleno':{'price':1000000,'model':1},    #HERE MARUTI:BALENO:PRICE,MODEL ARE VALUES.
                'scross':{'price':1100000,'model':1}     #Left side = key $ Right side = value.
               },
      'hundai':{'i10':{'price':1200000,'model':1},
                'creta':{'price':1600000,'model':1}
               },
      'kia':{'seltos':{'price':1900000,'model':1},
             'sonet':{'price':1500000,'model':1}
            }
     },
     'petrol':{'maruti':{'baleno':{'price':700000,'model':1},
                         'scross':{'price':800000,'model':1}
                        },
               'hundai':{'i10':{'price':700000,'model':1},
                         'creta':{'price':1200000,'model':1}
                        },
               'kia':{'seltos':{'price':1400000,'model':1},
                      'sonet':{'price':1100000,'model':1}
                     },
               'tata':{'altroz':{'price':700000,'model':1},
                       'punch':{'price':600000,'model':1}
                      }
              },
     'diesel':{'maruti':{'baleno':{'price':1000000,'model':1},
                         'scross':{'price':900000,'model':1}
                        },
               'hundai':{'i10':{'price':800000,'model':1},
                         'creta':{'price':1400000,'model':1}
                        },
               'kia':{'seltos':{'price':1600000,'model':1},
                      'sonet':{'price':1200000,'model':1}
                     }
              }
}
b=input('ENTER THE NAME OF COMPANY')
for fuel_type,companies in car.items():
    for company,cars in companies.items():
        if b in company:
            print('\n'f'FUEL TYPE:-{fuel_type}')
            for car_name,details in cars.items():
                print(f'CARS:-{car_name} | PRICE:-{details['price']} | MODEL:-{details['model']}')
# Out:
# ENTER THE NAME OF COMPANY kia
# FUEL TYPE:-ev
# CARS:-seltos | PRICE:-1900000 | MODEL:-1
# CARS:-sonet | PRICE:-1500000 | MODEL:-1
#
# FUEL TYPE:-petrol
# CARS:-seltos | PRICE:-1400000 | MODEL:-1
# CARS:-sonet | PRICE:-1100000 | MODEL:-1
#
# FUEL TYPE:-diesel
# CARS:-seltos | PRICE:-1600000 | MODEL:-1
# CARS:-sonet | PRICE:-1200000 | MODEL:-1

# %%
#SEARCH BY PRICE:-
#Search by Company (Kia,Hundai,Maruti...):-
car={'ev':                                  #HERE 'EV'-->K means keys
     {'maruti':{'baleno':{'price':1000000,'model':1},    #HERE MARUTI:BALENO:PRICE,MODEL ARE VALUES.
                'scross':{'price':1100000,'model':1}     #Left side = key $ Right side = value.
               },
      'hundai':{'i10':{'price':1200000,'model':1},
                'creta':{'price':1600000,'model':1}
               },
      'kia':{'seltos':{'price':1900000,'model':1},
             'sonet':{'price':1500000,'model':1}
            }
     },
     'petrol':{'maruti':{'baleno':{'price':700000,'model':1},
                         'scross':{'price':800000,'model':1}
                        },
               'hundai':{'i10':{'price':700000,'model':1},
                         'creta':{'price':1200000,'model':1}
                        },
               'kia':{'seltos':{'price':1400000,'model':1},
                      'sonet':{'price':1100000,'model':1}
                     },
               'tata':{'altroz':{'price':700000,'model':1},
                       'punch':{'price':600000,'model':1}
                      }
              },
     'diesel':{'maruti':{'baleno':{'price':1000000,'model':1},
                         'scross':{'price':900000,'model':1}
                        },
               'hundai':{'i10':{'price':800000,'model':1},
                         'creta':{'price':1400000,'model':1}
                        },
               'kia':{'seltos':{'price':1600000,'model':1},
                      'sonet':{'price':1200000,'model':1}
                     }
              }
}
b=int(input('ENTER THE PRICE:-'))
for fuel_type,companies in car.items():
    for company,cars in companies.items():
            for car_name,details in cars.items():
                if details['price']==b:
                    print(f'CAR NAME:-{car_name} | PRICE:-{details['price']} | MODEL:-{details['model']}')
# Out:
# ENTER THE PRICE:- 1200000
# CAR NAME:-i10 | PRICE:-1200000 | MODEL:-1
# CAR NAME:-creta | PRICE:-1200000 | MODEL:-1
# CAR NAME:-sonet | PRICE:-1200000 | MODEL:-1

# %%
#DICTIONARY COMPREHENSIVE:-
a={i:i*i for i in range(1,11)}
print(a)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
city_names=['ahemdabad','jaipur','surat','mehsana','chuama12']
city=[i.upper()+'-'+str(len(i)) for i in city_names]
print(city)
# Out:
# ['AHEMDABAD-9', 'JAIPUR-6', 'SURAT-5', 'MEHSANA-7', 'CHUAMA12-8']

# %%
'''d = {'a': 10, 'b': 20}

# Use both loops and print:
# 1. Only keys
# 2. Keys with values'''

# %%
d = {'a': 10, 'b': 20}
for k in d:
    print(k)
for k,v in d.items():
    print(k,v)
# Out:
# a
# b
# a 10
# b 20

# %%
d = {}
d[1] = 'a'      # {1: 'a'}
d[1.0] = 'b'    # overwrites same key
print(d)
# Out:
# {1: 'b'}

# %%
a=[1,2,2,3,3,3]
freq={}
for i in a:
    if i in freq:
        freq[i]=freq[i]+1
    else:
        freq[i]=1
print(freq)
# Out:
# {1: 1, 2: 2, 3: 3}

# %%
emp = {
 'emp101': {'name':'kd','salary':20000},
 'emp201': {'name':'rutu','salary':23000},
 'emp301': {'name':'meet','salary':25000}
}
for k,v in emp.items():
    if v['salary']>=25000:
        print(k,v['name'],v['salary'])
# Out:
# emp301 meet 25000

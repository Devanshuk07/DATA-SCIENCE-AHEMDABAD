# %%
'''MODULES:-
PYTHON FILE WHICH CONTAIN FUNCTION.

# %%
'''IN BUILT MODULE:-(ITS MAINLY FOR INTERACTING WITH OS 
sys os
datetime
request
math 
random etc...

# %%
import os
print(os.listdir('.'))
# Out:
# ['.ipynb_checkpoints', 'BASIC DATA STRUCTURE', 'FILTER FUNCTION.ipynb', 'FUNCTION.ipynb', 'LAMBDA FUNCTION.ipynb', 'LIBRARIES INFO.ipynb', 'MAP FUNCTION.ipynb', 'MODULES.ipynb', 'PROGRAM LAB TASK.ipynb', 'REDUCE FUNCTION.ipynb']

# %%
import os
print(os.listdir('F:\\DATA SCIENCE-AHEMDABAD\\CORE PYTHON\\BASIC'))
# Out:
# ['.ipynb_checkpoints', 'CHARACTOR--STRINGS.ipynb', 'CONDITIONAL STATEMENT.ipynb', 'CONTROL STATEMENTS IN LOOPS.ipynb', 'DATA TYPE.ipynb', 'EXAMPLE OF FOR LOOPS.ipynb', 'EXAMPLES OF CONDITION.ipynb', 'INPUT FUNCTION.ipynb', 'INTRO.ipynb', 'LOOPS.ipynb', 'METHOD AND FUNCTION OF STRING.ipynb', 'Operators.ipynb', 'Practical Problems.ipynb']

# %%
import os
lst=os.listdir('F:\\DATA SCIENCE-AHEMDABAD\\CORE PYTHON\\BASIC')
for i in lst:
    print(i)
# Out:
# .ipynb_checkpoints
# CHARACTOR--STRINGS.ipynb
# CONDITIONAL STATEMENT.ipynb
# CONTROL STATEMENTS IN LOOPS.ipynb
# DATA TYPE.ipynb
# EXAMPLE OF FOR LOOPS.ipynb
# EXAMPLES OF CONDITION.ipynb
# INPUT FUNCTION.ipynb
# INTRO.ipynb
# LOOPS.ipynb
# METHOD AND FUNCTION OF STRING.ipynb
# Operators.ipynb
# Practical Problems.ipynb

# %%
'''LABTASK:- PRINT FILENAME AND CHECK IF IT IS SUBFOLDER THEN DIPLAY THE FILE OF THAT FOLDER ALSO.

# %%
#create dict:-
os.makdic()

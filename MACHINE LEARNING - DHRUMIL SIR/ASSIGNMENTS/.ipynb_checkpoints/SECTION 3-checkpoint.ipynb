# %%
'''List three apps you use daily (such as Zomato, Instagram, or Flipkart) and describe one feature in each app that likely uses machine learning.
For each, state whether it is an example of supervised, unsupervised, or reinforcement learning.'''

# THREE APPS ARE FLIPKART , YOUTUBE , SWIGGY...
''' FROM MY POINT OF VIEW I CAN SAY THAT THIS ALL AAPS ARE USING SUPERVISED LEARNING AS BECAUSE IT HAS DATA OF MILLIONS OF USERS..
AND THE DATA CONTAINS LIKES,DISLIKES, FREQUETLY BROUGHT, FREQUENTLY VISITED THAT ALL DATA...
SO IF WE CREATE A MODEL AND TRAIN IT WITH THIS DATA THEN IT WILL SURELY HELPS IN UNDERSTANDING USERS NEED,TASTE,LIKES AND DISLIKES FOR FUTURE PREDICTION...
THAT A MODEL WITH SUPERVISED LEARNING CAN DO AS IT ALREADY HAS ALL THE DATA OF PERTICULAR USER.

# %%
'''
Given the following scenarios, classify each as supervised, unsupervised, or reinforcement learning: 
1) Netflix recommending movies based on your watch history, 2) Spotify grouping similar songs into playlists, 
3) A self-driving car learning to park by trial and error. Write your answers with a one-line explanation for each choice.


1) SUPERVISED LEARNING.
2) UNSUPERVISED LEARNING JUST BY FINDING PATTERNS.
3) REINFORCEMENT LEARNING BY TRIAL AND ERROR.'''

# %%
'''Draw a simple diagram (hand-drawn or digital) showing the basic ML workflow: Data → Preprocessing → Modeling → Evaluation → Deployment. 
Under each step, write a one-line example of what happens at that stage for a food delivery app like Swiggy.

Basic Machine Learning Workflow – Swiggy Example

1. Data → Collect customer orders, restaurant ratings, delivery times, prices, locations, etc.

⬇️

2. Preprocessing → Clean the data by removing missing values, duplicates, and converting categorical data into numerical form.

⬇️

3. Modeling → Train an ML model to predict things like delivery time or which restaurant a customer may prefer.

⬇️

4. Evaluation → Test the model and check its performance using metrics such as accuracy, MAE, RMSE, etc.

⬇️

5. Deployment → Put the trained model into the Swiggy app so it can make predictions for real users.'''

# %%
'''Imagine you are building a spam filter for WhatsApp messages. Write a short paragraph explaining how traditional programming would 
approach this problem versus how machine learning would approach it.<br><br><em><strong>Hint:</strong> Focus on rules vs learning from data.</em>

AS WE TALK FOR TRADITIONAL PROGRAMMING IT WILL WORK LIKE WE HAVE TO WRITE FULL CODE AND ALSO THAT CODE WILL CONTAIN IF-ELSE CONDITION.
AND WE HAVE TO GIVE MANY WORDS THAT IS BASED ON HOW SCAMMERS APPROCH AND GIVE MESSAGES AND WHAT IS THE PATTERN THAT PERTICULAR WORDS HAVE TO BE TAKEN FROM EACH MESSAGE AND 
WE HAVE TO PUT CONDITIONS THAT GIVE IF THIS WORDS THEN GIVE ERROR OR SCAM IN RETURN.

ALTHOUGH AFTER A LONG CODE.THEIR ARE MANY CHANCES THAT MANY WORDS AND FORGOTTEN OR NOT BEEN TAKEN AND THAT COULD CAUSE ERROR OR CANNOT BE DETECTED.

NOW WITH THE MACHINE LEARNING - WE CREATE A MODEL THAT HAS THIS SPECIFIC WORK THAT WHEN WE GIVE DATA IT READS UNDERSTAND TRAIN FROM THAT DATA AND
IT USES ITS OWN THINKING TO CHECK WEATHER A MESSAGE IS SCAM OR NOT... SO MACHINE LEARNING HAS MUCH MORE ACCURACY , NO LONG CODES... AND NO FAILURE OUTPUTS.

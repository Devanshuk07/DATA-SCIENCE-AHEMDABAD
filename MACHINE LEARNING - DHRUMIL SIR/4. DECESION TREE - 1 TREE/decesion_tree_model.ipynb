# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('decision_tree.csv')
df.head()
# Out:
#    Study_Hours  Attendance_Percent  Previous_Score Result
# 0          7.9                  89              62   Pass
# 1          4.7                  84              43   Fail
# 2          8.7                  74              41   Pass
# 3          7.1                  94              47   Pass
# 4          1.4                  47              67   Fail

# %%
x=df[['Study_Hours','Attendance_Percent','Previous_Score']]
y=df['Result']
x_train,x_test,y_train,y_test=train_test_split(
    x,
    y,
    train_size=0.80,
    random_state=42
)

# %%
model=DecisionTreeClassifier(max_depth=5,random_state=42)
model.fit(x_train,y_train)
pred=model.predict(x_test)
pred
# Out:
# array(['Fail', 'Fail', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Fail',
#        'Fail', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail',
#        'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Pass',
#        'Fail', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Fail', 'Fail',
#        'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Pass',
#        'Fail', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass',
#        'Fail', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Pass',
#        'Pass', 'Pass', 'Fail', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail',
#        'Pass', 'Pass', 'Pass', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail',
#        'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Fail', 'Fail', 'Fail',
#        'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail',
#        'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass', 'Fail',
#        'Pass', 'Fail', 'Pass', 'Fail'], dtype=object)

# %%
acc=accuracy_score(y_test,pred)
acc
# Out:
# 0.88

# %%
# Take input from user
hours = float(input("Enter Study Hours: "))
attendance = float(input("Enter Attendance Percentage: "))
score = float(input("Enter Previous Score: "))

# Make dataframe with same columns used during training
new_data = pd.DataFrame({
    'Study_Hours': [hours],
    'Attendance_Percent': [attendance],
    'Previous_Score': [score]
})

# Predict
prediction = model.predict(new_data)

print("Prediction:", prediction[0])
# Out:
# Prediction: Pass

# %%
'''
1) LINEAR --- REGRESSION
EX:- FOR NUMBER PREDICTION...can take one or multiple input columns (features) and predicts one continuous numerical output.”

2) LOGISTIC  --- CLASSIFICATION  // DATA SET IS LESS
EX:- FOR (YES / NO)(PASS/FAIL) LIKE STOCK BUY OR NOT THEN USE LOGISTICS.

3) KNN  ---  CLUSTER // CLASSIFICATION DATA -- CLUSTER
EX:- AIRTEL - 10 CR CUSTOMER GROUP DIVIDE...ON SERVICE..
EX:- FLIPKART -- 100 CR HOW YOU USE IT WILL DIVIDE UPON IT LIKE SILVER ,GOLD , BLACK,
SO IF YOU WANNA TO MAKE GROUP THEN KNN IS BEST...

4) DECESION TREE
5) RANDOM FOREST
6) XGBOOST
THIS THREE WORKS FOR MAKING TREES ONLY....THIS IS FOR LARGE DATA(MORE COLUMN/ROWS)AND BEST FOR CLASSIFICATION... USE XGBOOST ONLY...

# %%
'''API
ML HAS LIBS = JOBLIB AND PICKEL
LIB IS USED FOR MODEL DATA SAVE AND LOAD
METHOD IN PYTHON :-- DUMP AND LOAD.
DUMB FOR SAVE.
LOAD FOR LOAD.
FASTAPI
UVICORN - SERVER  ,,, PIP INSTALL UVICORN /// ALSO PIP INSTALL FASTAPI
UVICORN  HOW TO RUN :-
UVICORN FILENAME:APP --RELOAD.(YOUR SERVER WILL BE RUN TILL YOU TERMINATE IT OR GET AND ERROR)

API :- FASTAPI/FLASK/DJANGO  DJANGO IS USED FOR BOTH API AND ALSO FOR FRONTEND DEVELOPING.

**DIFFERENCE BETWEEN API VS MICRO SERVICE...
-LET YOU MAKE 15 API FOR 1 PROJECT AND FOR 1 DATABASE ONLY ----> ALL 15 API REQUEST AND DATA IS GOING FOR 1 SAME DATABASE AND SAME SERVER.
THIS TYPE OF ARCHITECTURE IS CALLED MONOLATHIC ARCHITECTURE.
-EVERY API FOR 1 PROJECT IS DEPLOY TO 1 DATABASE/SERVER THIS IS MONOLATHIC ARCHITECTURE.

IN ZOMATO REAL LIFE IN 1 DAY == 5LAKH API IS CALLED AND FOR EVERY REQUEST IT WILL GO TO SERVER...AND SERVER IS HANDLING THIS ALL REQUEST.
SERVER HAS LOAD FIX LIKE 500-1000,ALSO FOR ZOMATO 2LAKH,5LAKH....AND MORE THAN THAT REQUEST IT WILL WENT DOWN...
SO IN THAT PLACE THEY DONT USE MONOLATHIC BUT IT WILL USE MICRO SERVICES FOR FULL PROGRAM...
1ST PROGRAM IS MADE FOR MONOLATHIC BUT DUE TO MORE TRAFIC IT WILL TAKE MICRO SERVICES...
MICRO SERVICE :- IT WILL SEPERATE DIFFERENT SERVER FOR SEPERATE USAGE ....
ADVANTAGE :-LOAD WILL BE DIVIDED INTO MANY SERVERS...
DISADVANTAGE :- IT WILL COST HIGH ANS MANY SERVER WILL BE USED.

NGIX :-- USED FOR THAT IT WILL DISTRIBUTE LOAD EVEN IN MICRO SERVICES ITS A PART OF MICRO SERVICES.

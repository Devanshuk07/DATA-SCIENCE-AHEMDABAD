# %%
'''RANDOM FOREST(ALGORITHM) :-- DECESION TREE:--WE HAVE USED TILL NOW SINGLE TREE
BUT RANDOM FOREST(ALGO) IS FOR MULTIPLE TREE...

LET WE HAVE 10 MULTI TREE GENERATED THEN WE WILL GIVE PROPRITY TO MAXIMUM TREE...MEANS WE HAVE MAXIMUM OUPUT.

RANDOM FOREST = REAL TIME PASS..
------------------------------------------------------------
IT IS USED FOR BOTH CLASSIFICATION AND FOR REGRATION ALSO...

IF NO OF TREES ARE == 5
AND IF WE WORKING WITH CLASSIFICATION THEN IT WILL TAKE DECESION FROM VOTING...
AND IF WE WORKING WITH REGRATION THEN IT WILL TAKE DECESION FROM AVERAGE...
------------------------------------------------------------
WHY THE NAME IS RANDOM ?  HOW IS BOOSTRAP SAMPLING WORKS...NO OF TREE PASS...WHEN WE WILL REMOVE BOOSTRAP IT WILL BE DECESION TREE ...
-THE CHANCES OF OVERFITING IS MORE IN DECESION TREE ,, OVERFITTING MEANS RATTA MARNA...
-LET WE HAVE IN DATA ....
A,B,C,D,E,F - ROWS       &&     x,y,z --FEATURES(COLUMNS)

THEN WHEN YOU WILL GIVE HOW MANY TREES TO GENERATE THAT IS == 3
THEN IN....THIS ALSO WE HAVE TO GIVE MAX_DEPTH = 2/3/4 LIKE DECESION TREE ONLY...BUT IT WILL CREATE MANY TREES NOT LIKE DECESION TREE ONLY 1 TREE...
IT WILL TAKE EVERY FEATURE IN EACH TREE...
TREE 1:-
A,B,C,D,E,F       -- FROM STUDY HRS

TREE 2:-
B,B,C,D,D,A   (SAME 6)      -- FROM MARKS...

TREE 3:-
RANDOM

FOR EVERY FEATURES(COLUMN) IT WILL GENERATE EACH TREE...'''

# %%
'''YOU HAVE TO IMPORT 
FROM SKLEARN.ENSEMBLE IMPORT RANDOM FOREST....

THIS ENSEMBLE IS FOR MERGEING THE TREE THAT THIS RANDOM FOREST CREATE SEPERATELY...'''

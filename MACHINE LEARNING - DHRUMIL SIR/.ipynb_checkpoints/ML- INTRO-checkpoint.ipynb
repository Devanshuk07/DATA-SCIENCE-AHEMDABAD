# %%
'''WHAT IS MACHINE LANGUAGE ?
WE DON'T WORK WITH TRADITIONAL PROGRAMMING WE WILL WORK WITH 
MACHINE-DATA-UNDERSTAND IT - WILL LEARN - THEN GIVE OUTPUT.

RULES SET - FOR PROGRAM - LIKE THAT IT WORKS.

TYPES OF MACHINE LEARNING:-
1.SUPERVISED
2.UNSUPERVISED 
REINFORCEMENT - TESLA - CHESS GAME

* SUPERVISED - WILL GIVE OUR MODEL QUESTION AND ANSWERS IN FORM OF DATA.
*UNSUPERVISED - WILL JUST GIVE IT QUESTION AND NO ANSWER.

---------------------------------------------------------------------
ML LIFE CYCLE:--( WE DONT USE IF-ELSE PYTHON CODE JUST WE USE ALGORITHM THAT IS CREATED FOR ML- SO IT CAN LEARN BY ITSELF)

1. PROBLEM STATEMENT :- FOR WHICH PROB WE HAVE TO CREATE AI ? // PROJECT DEFINATION

2. DATA COLLECTION :- WHICH RESOURCE AVAILABLE FOR COLLECTION.
EX:-1.KAGGLE - WEBSITE 
    2.API - MOSTLY FROM THIS WE GET DATA
    3.AI - CHATGPT,GEMENI
    4.SCRAPING - FROM CLOUD

3. DATA PREPARATION - SOME MISSING ,NULL WILL BE CLEANED.

4. FEATURES ENGINNERING - GENERATING COLUMN FROM AVAILABLE DATA, MEANS PROVIDING EXTRA DETAILS THROUGH COLUMNS.

-TILL THIS DATA ANALITICES WILL DO THIS AND IF WE GOT 1 LAKH DATA THEN IT WILL USE 80% OF DATA TO AI/ML DEVELOPER TO MAKE MODEL LEARN FROM IT.
REST 20% DATA WILL BE USED TO TEST THE SAME MODEL WEATHER IT IS GOOD OR NOT/PERFECT OR NOT.

5. TRAIN TEST SPLIT - 80-% FOR TRAINING REST 20% FOR DATA TESTING

6. MODEL SELECTION - WHICH ALGORITH YOU WANT TO USE FROM THE BASE OF OUR REQUIRMENT
ALGORITH :- IS A SET OF INSTRUCTIONS THAT IS PREDEFINED AND ACCORDING TO THAT SETS ALGORITHM WILL WORK.YOU CANNOT CUSTOMIZE ALGORITHM BY YOUR OWN.

7. MODEL TRAINING - YOU HAVE TO GIVE TRAINING AND YOU HAVE TO GIVE 80% DATA TO THAT MODEL SO IT CAN START SELF LEARNING.

8. MODEL EVOLUTION / ACCURACY - WE WILL SEE THE ACCURACY WHAT IT GIVES.
9. HYPERPARAMETER TUNING - WILL TRAINING MODEL YOU HAVE USED VALUES FOR X AND Y THEN IN THIS WE WILL CHANGE OUR X AND Y THEN WE WILL GIVE TRAINING AGAIN WITH DIFFERENT VALUES FOR X AND Y.
10. DEPLOYMENT - AFTER ALL WE GOT ACCURACY THAT WE WANT THEN AFTER THAT WE WILL MOVE THAT MODEL FROM OUR PC TO LIVE SERVER SO CUSTOMER CAN ACCESS IT.
11. MONITORING - THEN WE CONTINOUSLY KEEP MONITORING IT.
12. RETRAINING - WHEN TIME PASSES NES DATA WILL BE GENRATED AND WE HAVE TO GIVE IT NEW DATA ALSO FOR THAT ALSO WE HAVE TO TRAIN IT.

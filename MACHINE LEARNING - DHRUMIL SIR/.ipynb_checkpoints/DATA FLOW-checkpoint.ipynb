# %%
'''
1. DATA SET - DATA COLLECTION
    ROW AND COLUMN

    SNAME MARKS ATTENDENCE RESULT

2. FEATURES AND TRAGET - DIVIDE THE DATA INTO FEATURE AND TARGET

3. TYPES OF DATA
    1.STRUCTURED DATA - EXCEL , CSV, MYSQL // STORED IN FORM OF TABLE
    2.UNSTRUCTURED DATA - MONGO DB, REDIS // DATA-BASE ,,,DATA LIKE IN FORM OF IMAGE,TEXT,WORD,PDF,VIDEO
    3.SEMI STRUCTURED DATA - API - JSON - KEY AND VALUES, XML -HTML TAG FORM.

4. DATA PRE-PROCESSING // LIBRARIES
    1.MISSING VALUES
    2.NULL - DUPLICATE VALUES

5. ENCODING - DATA SET = DATA WE HAVE IN TEXT FORM - ALGORITHM UNDERSTAND IN NUMBERS - SO TO CONVERT IT INTO NUMBER
    FOR ML IT HAS TWO IN-BUILT METHOD:-
    1. LABEL ENCODING.
    2. ONE-HOT ENCODING. (BEST)

6. SCALING - WE HAVE DATA SET IN WHIHC LET ONE COLUMN = SALARY,,IF ANY SALARY IS 15 LAKH AND ONE HAS 5000 AND ONE HAS 5 LAKH 
AND ALSO ONE COLUMN IS AGE THEN IT HAS FIXED AGE IN 3 DIGIT ONLY.LIKE 50,80,101
IN THIS DATA SET - MODEL WHICH HAS MORE AMOUNT HAS MORE PRIORITY IS GIVEN TO IT BY MODEL.
DUE TO THIS MODEL WILL NOT GET LEARN FROM IT PROPERLY.MODEL GET BIOS WHICH DIGIT IS BIGGER - IT WILL GIVE MORE PRIORITY

SO SCALING WILL HELP IT IN GIVING RANGE FROM 0-1 SO NO-ONE WILL BE PRIORITIZED AND NO BIOS BY MODEL.

7. PREDICTION :- TEST = AGE IF ENTERED 45- MODEL WILL CHECK AND GIVE PREDICTED/TARGET SALARY 45000 THIS IS PREDICTION BY MODEL 
BY FIRST COMPLETELY LEARNING THE DATA SET.

8. ACCURACY :-FROM 100 / 92 TIMES IT WILL GIVE TRUE ANSWER THAT MEANS THE ACCURACY OF THE MODEL.

9. LOSS :- DIFFERENCE BTW ACTUAL VALUE - PREDICTED VALUE = 45K-40K = 5K

10. EPOCK = CSV HAS = 100 DATA = I PASS EPOCK=3 THEN MY ALGORITH WILL READ MY CSV FOR 3 TIMES IF EPOCK=10 THEN FOR 10 TIMES.

11. LEARNING RATE :- TELLING MACHINE TO LEARN THE DATA SLOW / FAST THAT WE HAVE TO TELL (PARAMETERES ARE 0.1,0.2,0.3)

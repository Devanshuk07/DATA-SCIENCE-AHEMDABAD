# %%
'''KNN ALGORITHM IS ONLY FOR CLASSIFICATION MEANS IT IS FOR (OUPUT :- YES/NO ,,PASS/FAIL ,, 0/1 ONLY.)

HOW TO USE KKN ALGORITHM:-
1. STANDARD SCALER :- Z= INPUT - MEAN / STD
INITIALIZATION = OBJECT

NOW FOR TRAINING :-- METHOD IS FIT_TRANSFORM THAT IS Z=INPUT-MEAN/STD FOR X-TRAIN.
FOR TESTING :-- METHOD IS SCALER.TRANSFORM FOR X-TEST.
-------------------------------------------------------------------------------------------------------
****************** CODE ************************

AFTER THIS :---
x_train,x_test,y_train,y_test=train_test_split(
    x,y,train_size=0.80,random_state=42
)

WE HAVE TO WRITE:--
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)


THEN,
MODEL=KNEIGHBORCLASSIFIER(N_NEIGHBORS=3)  HERE START FROM 3 THEN CHECK ACCURACY THEN 5 THEN 7 THEN 11 THE MORE ACCURACY IN WHICH NO. ,,WE HAVE TO USE THAT NUMBER.
model.fit(x_train,y_train)
pre=model.predict(x_test)

THEN,
ACCURACY=ACCURACY_SCORE(Y_TRAIN,Y_TEST)

THEN,
AT LAST WE HAVE TO RUN DATA FROM SCALAR
newdata=pd.DataFrame({
  "Study Hours":[hrs]
}) 

mynewdata=scaler.transform(newdata)                   this is important.as you are giving data to knn algorithm then it will predict for pass and fail.
predication= model.predict(mynewdata)
print(predication[0])

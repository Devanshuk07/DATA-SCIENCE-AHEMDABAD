# %%
'''RE-INFORCEMENT LEARNING WORKS ON:--

1) AGENT :- 

2) ACTION :- LEFT SIDE DRIVE,IF SOME-ONE COMMING THEN RIGHT SIDE DRIVE...

3) ENVIRNMENT :- FOR BETTER AI DRIVING ENVIRNMENT IS CAR WE HAVE TO GIVE CAR SO AGENT AI CAN UNDERSTAND IT BETTERLY...

4) LEARNING

AI= API - WEBSITE - INTEGRATION
SEMI CONDUSTOR CHIPSET...

1) SOFTWARE  2) HARDWARE-CHIPS -CODING

REINFORCEMNET LEARNING DONT WORK IN WEBSITE IT WORKS WITH SOFTWARE AND HARDWARE-CHIPS. WITH CODING AND EMBEDING SOFTWARE/CODE DONE ON CHIP...

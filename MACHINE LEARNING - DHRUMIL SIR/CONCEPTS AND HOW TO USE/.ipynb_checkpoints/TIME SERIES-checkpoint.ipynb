# %%
'''WHAT IS TIME SERIES ...?

TILL WE HAVE IN DATA ....
AGE   SALARY     MARKS    NAME
23     23000      92      DEVANSHU

THIS DATA HAS NO RELATION WITH TIME/ORDER....

TIME SERIES MEANS TIME AND DATA BOTH ARE RELATED TO EACH OTHER....
LET WE HAVE DATA OF COMPANY...
MONTH    SALES
JAN       100
FEB       200
MAR       700

IF WE HAVE TO PREDICT IN APR HOW MUCH SALES IT WILL BE SO IN THIS TIME IS IMPORTANT...
EX ARE ... RAIN PREDICTION,,,TEMPERATURE,,,STOCK MARKET,,, FORCASTING,,,WEBSITE VISITORS...

NOW LET WE HAVE KOHLI  AND WE WANNA TO PREDICT NEXT MATCH SCORE...
THEN WE HAVE LAST 10 YEARS HIS HISTORY BUT WE PREDICT UPON ITS CURRENT FORM SO WE ONLY WANT HIS LAST 5-6 INNINGS SOO....

SO WE WILL DIVIDE IT INTO QUATERS.. MEANS 1/4TH....
OUR MODEL WILL ALSO DIVIDE THE DATA INTO QUATER....SO IT CAN PREDICT PROPERLY UPON LATEST/CURRENT TRENDING TREND....

LETS WE HAVE DATA IN EXCEL // API  STORES IT IN DATABASE ... THEN WE JUST HAVE TO GET CURRENT DATA...
(WE CAN USE WHERE/SELECT * FROM ... LIKE THIS IN PYTHON TO ACCESS DATABASE AND THEN SAVE IT TO_CSV IN NEW EXCEL FILE...)
BUT FOR THIS COMPANY USES A PIPELINE WHICH DO THIS WORK ONLY BUT AUTOMATICALLY... AND THAT PIPELINE WE HAVE TO CREATE...

TIME SERIES WORK ON THIS ....
1) TREND --CURRENT TRENDING THINGS....IN ANY MONTH SALES INCREASE...
2) SEASON -- SEASONAL SALE LIKE ICE-CREAM,PERTICULAR SEASON SALES INCREASE...
3) NOISE --THIS IS LIKE OUTLIER SUDDEN INCREASE IN SALES THEN CURRENT TREND...
4) CYCLIC -- TREAND NOT FIX FREQUENTLY UP THEN DOWN THEN UP AGAIN DOWN LIKE RAIN PREDICTION....

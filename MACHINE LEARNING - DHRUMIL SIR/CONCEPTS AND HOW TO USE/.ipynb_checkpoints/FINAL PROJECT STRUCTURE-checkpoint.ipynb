# %%
'''ALL FILES/FOLDERS:-

iphone_prediction/
│
├── .github/
│   └── workflows/
│       └── deploy.yml
│
├── Dockerfile
├── main.py
├── index.html
├── iphone_model.pkl
├── requirements.txt
└── .gitignore          ← recommended
'''

# %%
'''And externally you have:
GitHub       → source code
Docker Hub   → Docker image
Aiven        → MySQL database
Render       → live web service'''
